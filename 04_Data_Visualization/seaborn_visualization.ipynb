# %% [markdown]
# # Data Visualization with Seaborn
#
# Author: Gaurav Gohil
#
# Seaborn is a powerful Python library built on top of Matplotlib.
# It provides a high-level interface for creating attractive and informative statistical graphics.
#
# ---
#
# ## Topics Covered
#
# 1. Introduction to Seaborn
# 2. Line Plot
# 3. Bar Plot
# 4. Histogram
# 5. Box Plot
# 6. Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Load Sample Dataset
#
# Seaborn provides built-in datasets for practice.

# %%
df = sns.load_dataset("tips")

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 2. Line Plot

# %%
sns.lineplot(x="total_bill", y="tip", data=df)
plt.title("Line Plot")
plt.show()

# %% [markdown]
# ## 3. Bar Plot

# %%
sns.barplot(x="day", y="total_bill", data=df)
plt.title("Bar Plot")
plt.show()

# %% [markdown]
# ## 4. Histogram

# %%
sns.histplot(df["total_bill"])
plt.title("Histogram")
plt.show()

# %% [markdown]
# ## 5. Box Plot

# %%
sns.boxplot(x="day", y="total_bill", data=df)
plt.title("Box Plot")
plt.show()

# %% [markdown]
# ## 6. Heatmap

# %%
correlation = df.corr(numeric_only=True)

sns.heatmap(correlation, annot=True)
plt.title("Heatmap")
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this notebook we learned how to create visualizations using Seaborn:
#
# - Line plot
# - Bar plot
# - Histogram
# - Box plot
# - Heatmap
#
# Seaborn helps create more attractive and meaningful visualizations compared to basic Matplotlib.

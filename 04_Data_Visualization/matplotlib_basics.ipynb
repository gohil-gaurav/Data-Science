# %% [markdown]
# # Data Visualization with Matplotlib
#
# Author: Gaurav Gohil
#
# Matplotlib is one of the most widely used libraries in Python for data visualization.
# It allows us to create various types of charts to better understand data.
#
# ---
#
# ## Topics Covered
#
# 1. Line Plot
# 2. Bar Chart
# 3. Histogram
# 4. Scatter Plot
# 5. Customizing Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1. Line Plot
#
# Line plots are used to visualize trends over time.

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

plt.plot(x, y)
plt.title("Line Plot Example")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()

# %% [markdown]
# ## 2. Bar Chart
#
# Bar charts are used to compare categories.

# %%
categories = ["A", "B", "C", "D"]
values = [5, 7, 3, 8]

plt.bar(categories, values)
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# ## 3. Histogram
#
# Histograms are used to show the distribution of numerical data.

# %%
data = np.random.randn(100)

plt.hist(data)
plt.title("Histogram Example")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## 4. Scatter Plot
#
# Scatter plots are used to observe relationships between two variables.

# %%
x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y)
plt.title("Scatter Plot Example")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.show()

# %% [markdown]
# ## 5. Customizing Plots
#
# We can customize plots by adding colors, markers, and styles.

# %%
x = [1,2,3,4,5]
y = [5,10,15,20,25]

plt.plot(x, y, marker='o', linestyle='--', color='blue')
plt.title("Customized Line Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this notebook we learned:
#
# - Line plots
# - Bar charts
# - Histograms
# - Scatter plots
# - Plot customization
#
# Data visualization is essential for understanding data and presenting insights clearly.
